# %%
import os
import zipfile
import random
# %tensorflow_version 2.x
import tensorflow as tf
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from shutil import copyfile

# %%
# !wget --no-check-certificate \
    "https://storage.googleapis.com/datsets/Curruency%20Recognition%20New%20Dataset/Basic%20Dataset%20Up%20Down%20Center.zip"\
    -O "/tmp/currency_dataset.zip"

local_zip = '/tmp/currency_dataset.zip'
zip_ref   = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()
# Out:
# --2020-06-01 09:53:26--  https://storage.googleapis.com/datsets/Curruency%20Recognition%20New%20Dataset/Basic%20Dataset%20Up%20Down%20Center.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.194.128, 2404:6800:4003:c00::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.194.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 658463834 (628M) [application/x-zip-compressed]
# Saving to: ‘/tmp/currency_dataset.zip’
#
# /tmp/currency_datas 100%[===================>] 627.96M   210MB/s    in 3.0s
#
# 2020-06-01 09:53:29 (210 MB/s) - ‘/tmp/currency_dataset.zip’ saved [658463834/658463834]

# %%
print(len(os.listdir('/tmp/Basic Dataset/Center')))
print(len(os.listdir('/tmp/Basic Dataset/Up')))
print(len(os.listdir('/tmp/Basic Dataset/Down')))
# Out:
# 100
# 100
# 100

# %%
os.mkdir('/tmp/Test1')
os.mkdir('/tmp/Test1/Up')
os.mkdir('/tmp/Test1/Down')
os.mkdir('/tmp/Test1/Center')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-66-736643732341> in <module>()
# ----> 1 os.mkdir('/tmp/Test1')
#       2 os.mkdir('/tmp/Test1/Up')
#       3 os.mkdir('/tmp/Test1/Down')
#       4 os.mkdir('/tmp/Test1/Center')
#
# FileExistsError: [Errno 17] File exists: '/tmp/Test1'

# %%
import shutil
for j in ['Up','Down','Center']:
  for i in range(1,101,10):
    shutil.move('/tmp/Basic Dataset/{}/{}.jpg'.format(j,i), '/tmp/Test1/{}/{}.jpg'.format(j,i))

# %%
print(len(os.listdir('/tmp/Basic Dataset/Center')))
print(len(os.listdir('/tmp/Basic Dataset/Up')))
print(len(os.listdir('/tmp/Basic Dataset/Down')))
print(len(os.listdir('/tmp/Test1/Up')))
print(len(os.listdir('/tmp/Test1/Down')))
print(len(os.listdir('/tmp/Test1/Center')))
# Out:
# 90
# 90
# 90
# 10
# 10
# 10

# %%
TRAINING_DIR = "/tmp/Basic Dataset/"
# Experiment with your own parameters here to really try to drive it to 99.9% accuracy or better

train_datagen = ImageDataGenerator(
    rescale=1./255,
      fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(TRAINING_DIR,
                                                    batch_size=5,
                                                    class_mode='categorical',
                                                    target_size=(1300,1000))

VALIDATION_DIR = "/tmp/Test1"

# Experiment with your own parameters here to really try to drive it to 99.9% accuracy or better
validation_datagen = ImageDataGenerator(rescale=1./255,fill_mode='nearest')
validation_generator = validation_datagen.flow_from_directory(VALIDATION_DIR,
                                                              batch_size=5,
                                                              class_mode='categorical',
                                                              target_size=(1300, 1000))
# Out:
# Found 270 images belonging to 3 classes.
# Found 30 images belonging to 3 classes.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(64, (5, 5), activation='relu', input_shape=(1300, 1000, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Flatten(),
    # tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(128, activation='relu'),
    
    tf.keras.layers.Dense(3, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-62-010818d5839e> in <module>()
#      12     tf.keras.layers.Dense(128, activation='relu'),
#      13
# ---> 14     tf.keras.layers.Dense(3, activation='softmax')
#      15 ])
#      16
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/base.py in _method_wrapper(self, *args, **kwargs)
#     454     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     455     try:
# --> 456       result = method(self, *args, **kwargs)
#     457     finally:
#     458       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py in __init__(self, layers, name)
#     127       tf_utils.assert_no_legacy_layers(layers)
#     128       for layer in layers:
# ...

# %%
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_27 (Conv2D)           (None, 1296, 996, 64)     4864
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 648, 498, 64)      0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 646, 496, 32)      18464
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 323, 248, 32)      0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 321, 246, 32)      9248
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 160, 123, 32)      0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 629760)            0
# ...

# %%
history = model.fit_generator(train_generator,
                              epochs=15,
                              
                              verbose=1,
                              validation_data=validation_generator)
# Out:
# Epoch 1/15
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-59-fea3f48e0350> in <module>()
#       3
#       4                               verbose=1,
# ----> 5                               validation_data=validation_generator)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     322               'in a future version' if date is None else ('after %s' % date),
#     323               instructions)
# --> 324       return func(*args, **kwargs)
#     325     return tf_decorator.make_decorator(
#     326         func, new_func, 'deprecated',
#
# ...
